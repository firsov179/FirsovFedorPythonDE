# %%
from datetime import datetime
from datetime import timedelta

# %%
def task_1():
    date1_string = 'Wednesday, October 2, 2002'
    date1_format = '%A, %B %d, %Y'
    date1 = datetime.strptime(date1_string, date1_format)

    date2_string = 'Friday, 11.10.13'
    date2_format = '%A, %d.%m.%y'
    date2 = datetime.strptime(date2_string, date2_format)

    date3_string = 'Thursday, 18 August 1977'
    date3_format = '%A, %d %B %Y'
    date3 = datetime.strptime(date3_string, date3_format)

    print(date1)
    print(date2)
    print(date3)

# %%
task_1()
# Out:
# 2002-10-02 00:00:00
# 2013-10-11 00:00:00
# 1977-08-18 00:00:00

# %%
def date_range(start_date, end_date):
    try:
        start = datetime.strptime(start_date, '%Y-%m-%d')
        end = datetime.strptime(end_date, '%Y-%m-%d')

        if start > end:
            return []

        date_list = []
        current_date = start

        while current_date <= end:
            date_list.append(current_date.strftime('%Y-%m-%d'))
            current_date += timedelta(days=1)

        return date_list

    except ValueError:
        return []

# %%
print(date_range('2022-01-01', '2022-01-03'))

print(date_range('2022-01-03', '2022-01-01'))

print(date_range('2022-02-30', '2022-02-31'))
# Out:
# ['2022-01-01', '2022-01-02', '2022-01-03']
# []
# []
