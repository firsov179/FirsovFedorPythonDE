# %%
def task1(word):
    length = len(word)

    if length % 2 == 1:
        middle_index = length // 2
        print(f"{word} -> {word[middle_index]}")
    else:
        middle_index = length // 2
        print(f"{word} -> {word[middle_index - 1]}{word[middle_index]}")

# %%
task1('test')
task1('testing')
task1('hello')
task1('world')
task1('python')
# Out:
# test -> es
# testing -> t
# hello -> l
# world -> r
# python -> th

# %%
def task2(boys, girls):
    if len(boys) != len(girls):
        print("Внимание, кто-то может остаться без пары!")
        return

    sorted_boys = sorted(boys)
    sorted_girls = sorted(girls)

    print("Идеальные пары:")
    for i in range(len(sorted_boys)):
        print(f"{sorted_boys[i]} и {sorted_girls[i]}")

# %%
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
task2(boys, girls)

print()
print('*' * 100)
print()

boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard', 'Michael']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
task2(boys, girls)
# Out:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha
#
# ****************************************************************************************************
#
# Внимание, кто-то может остаться без пары!
